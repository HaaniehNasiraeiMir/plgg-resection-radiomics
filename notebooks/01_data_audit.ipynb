# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
DATA_DIR = PROJECT_ROOT / "data"

print("Working directory:", Path.cwd())
print("Data directory:", DATA_DIR)
print("Clinical file exists:", (DATA_DIR / "X_clinical.pkl").exists())
print("Radiomic file exists:", (DATA_DIR / "X_radiomic.pkl").exists())
# Out:
# Working directory: /Users/haanieh/Desktop/plgg-resection-radiomics/notebooks
# Data directory: /Users/haanieh/Desktop/plgg-resection-radiomics/data
# Clinical file exists: True
# Radiomic file exists: True

# %%
clinical = pd.read_pickle(DATA_DIR / "X_clinical.pkl")
clinical.head()
# Out:
#            Sex  Age at Diagnosis  Tumor Location  NF1  \
# SubjectID
# C1003557     1         -0.534356        1.123165    0
# C1026189     0         -0.764980       -0.727819    0
# C1032462     1         -1.161804       -1.250923    0
# C1046730     1         -0.499167        1.123165    0
# C1060998     1          1.640328        1.123165    0
#
#            Extent of Tumor Resection  Chemotherapy  Radiation     Cohort
# SubjectID
# C1003557                    0.333333             1          0  Discovery
# C1026189                    0.333333             1          0  Discovery
# C1032462                    1.000000             0          0  Discovery
# C1046730                    0.333333             1          0  Discovery
# C1060998                    1.000000             0          0  Discovery
